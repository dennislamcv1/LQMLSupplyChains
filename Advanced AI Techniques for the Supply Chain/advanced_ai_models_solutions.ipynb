# %%
### In this cell, we import the necessary packages.

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
### Part A (10 pts)

# Create the input and output data for the network to train on, as discuessed above.
# Store the input data as a 4 column numpy array called x_data
# Store the output data as a 1 column numpy array called y_data

x_data = np.zeros((2**4, 4))
y_data = np.zeros((2**4, 1))
current_input = [0, 0, 0, 0]
current_row = 0
while current_row < x_data.shape[0]:
    # Store the current input in the current row
    x_data[current_row, :] = current_input
    y_data[current_row, :] = sum(current_input) % 2
    # Create the next input
    current_input[3] += 1
    for i in range(3, -1, -1):
        if current_input[i] == 2:
            current_input[i] = 0
            current_input[i - 1] += 1
    # Iterate to the next row
    current_row += 1

# %%
### Part B (25 pts)

# 1 -- Network Initialization

# Initialize a simple sequential neural network model
model = Sequential()

### Add the following layers to 'model'.
# Hidden layer: 32 neurons (somewhat arbitrary), 'relu' activation 
# Output layer: 1 neurons (since it is binary classification), 'sigmoid' activation

model.add(Dense(units=32, input_dim=4, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Print a summary of what you just created
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                160
#
#  dense_1 (Dense)             (None, 1)                 33
#
# ...
# Total params: 193
# Trainable params: 193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 2 -- Network Compilation

# Compile. Loss function: binary crossentropy. Optimizer: stochastic gradient descent (SGD). Metrics: 'accuracy'
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
# 3 -- Network Training

# Number of epochs: 500 (i.e. how many times to loop over the training data)
# Batch size: 2 (how big our "random walk" samples should be)

model.fit(x_data, y_data, epochs=500, batch_size=3)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 1ms/step - loss: 0.7100 - accuracy: 0.5625
# Epoch 2/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7092 - accuracy: 0.5625
# Epoch 3/500
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7080 - accuracy: 0.5625
# Epoch 4/500
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7068 - accuracy: 0.5625
# Epoch 5/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7049 - accuracy: 0.5625
# Epoch 6/500
# 6/6 [==============================] - 0s 3ms/step - loss: 0.7020 - accuracy: 0.5625
# Epoch 7/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7019 - accuracy: 0.5625
# Epoch 8/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.7010 - accuracy: 0.5625
# Epoch 9/500
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6993 - accuracy: 0.6250
# Epoch 10/500
# ...

# %%
# 4 -- Network Evaluation

### Save the final cost of the loss model in a varaible called 'final_cost'.
### Save the final cost of the model on the test set in a variable called 'test_accuracy'.

loss_and_metrics = model.evaluate(x_data, y_data, verbose=0)

final_cost = loss_and_metrics[0]
test_accuracy = loss_and_metrics[1]

print("Final test cost: ", final_cost)
print("Final test accuracy: ", test_accuracy)
# Out:
# Final test cost:  0.6195344924926758
# Final test accuracy:  0.8125
